# %% [markdown]
# ## Build graph using TF operations

# %%
import tensorflow as tf
import numpy as np

# %%
x_train = [1, 2, 3, 4]
y_train = [0, -1, -2, -3]

tf.model = tf.keras.Sequential()
# units == output shape, input_dim == input shape
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=1))

# %% [markdown]
# ### GradientDescent (minimizing cost function)

# %%
sgd = tf.keras.optimizers.SGD(lr=0.1)  # SGD == standard gradient descendent, lr == learning rate

# %% [markdown]
# ### lost, cost function (mse)

# %%
from IPython.display import Image
size = 300,300
image1 = Image('costfunction.png')
image1

# %%
tf.model.compile(loss='mse', optimizer=sgd)  # mse == mean_squared_error, 1/m * sig (y'-y)^2

# %%
# prints summary of the model to the terminal
tf.model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit() executes training
tf.model.fit(x_train, y_train, epochs=200)

# predict() returns predicted value
y_predict = tf.model.predict(np.array([5, 4]))
# Out:
# Epoch 1/200
# 1/1 [==============================] - 0s 74ms/step - loss: 13.9874
# Epoch 2/200
# 1/1 [==============================] - 0s 2ms/step - loss: 6.4439
# Epoch 3/200
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0473
# Epoch 4/200
# 1/1 [==============================] - 0s 968us/step - loss: 1.5132
# Epoch 5/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.8159
# Epoch 6/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4947
# Epoch 7/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.3430
# Epoch 8/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2677
# Epoch 9/200
# 1/1 [==============================] - 0s 998us/step - loss: 0.2272
# Epoch 10/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2027
# Epoch 11/200
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1858
# Epoch 12/200
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1726
# ...

# %%
print(y_predict)
# Out:
# [[-3.997735 ]
#  [-2.9988346]]
